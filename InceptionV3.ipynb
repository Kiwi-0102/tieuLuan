# %% [markdown]
# # **1. Kết nối với Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG

# %% [markdown]
# # **2. Import thư viện**

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import cv2
import numpy as np
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score

# Keras and TensorFlow
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2

# %% [markdown]
# # **3. Đọc dữ liệu và gán nhãn**

# %%
# class list
classes = ["Sheath_Blight", "Leaf_Blast", "Leaf_Scald",
           "Brown_Spot", "Bacterial_Leaf_Blight", "Healthy_Rice_Leaf"]

labels = []
image_links = []
class_path ='/content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG'
# load and label emages
for class_name in classes:
    images = glob.glob(f'{class_path}/{class_name}/*.jpg')
    labels.extend([class_name] * len(images))
    image_links.extend(images)
# transfer data to dataframe
data = pd.DataFrame({'labels': labels, 'image_links': image_links})

# check the number of images per layer
data['labels'].value_counts().plot.bar()
plt.show()
print(data['labels'].value_counts())
# Out:
# labels
# Leaf_Blast               1748
# Sheath_Blight            1629
# Brown_Spot               1546
# Leaf_Scald               1332
# Bacterial_Leaf_Blight    1197
# Healthy_Rice_Leaf        1085
# Name: count, dtype: int64

# %% [markdown]
# # **4. Chia tập dữ liệu**

# %%
# split the test set (15%)
images_train_val, images_test, y_train_val, y_test = train_test_split(
    image_links, labels, stratify=labels, test_size=0.15, random_state=42)

print(f'Train + Val: {len(images_train_val)}, Test: {len(images_test)}')

 # split train and validation from the train_val set
images_train, images_val, y_train, y_val = train_test_split(
    images_train_val, y_train_val, stratify=y_train_val, test_size=0.176, random_state=42) # 0.176 * 85% = 15%

print(f'Train: {len(images_train)}, Val: {len(images_val)}, Test: {len(images_test)}')
# Out:
# Train + Val: 7256, Test: 1281
# Train: 5978, Val: 1278, Test: 1281

# %% [markdown]
# # **5. Tiền xử lý dữ liệu**

# %%
# load and resize emages
def load_and_resize_image(img_path, target_size=(229, 229)):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Error reading image: {img_path}")
        return None
    img_resized = cv2.resize(img, target_size)  # Resize emages
    img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)  # Đổi sang RGB (OpenCV đọc theo BGR)
    img_normalized = img_rgb / 255.0
    return img_normalized
# check emages size
for img_path in image_links:
    img = load_and_resize_image(img_path)
    if img is not None:
        # print proccessed emages
        print(f"Processed image shape for {img_path}: {img.shape}")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3114.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3230.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3323.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3145.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3199.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3154.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3128.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3143.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3117.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3320.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_338.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3341.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3376.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_346.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3328.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3364.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3466.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3338.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_341.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3438.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3370.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3397.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3465.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3413.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3461.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3356.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_345.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3382.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3331.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3429.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3456.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3422.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3428.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3415.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3533.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3675.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3688.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3665.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3542.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3560.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3681.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3622.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3483.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3502.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3619.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3529.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3509.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3553.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3635.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3528.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3584.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3586.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3596.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3631.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_353.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3510.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_370.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3645.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3550.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3689.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3604.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_366.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_35.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3639.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3558.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3950.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_394.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3711.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3861.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3870.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3852.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3853.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3952.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3909.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3793.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3847.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3971.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3705.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3759.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_387.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3818.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3882.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3867.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3826.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3906.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3817.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3948.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3718.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3933.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3883.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3863.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3899.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3775.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3808.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3777.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3823.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3875.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3854.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3761.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3898.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3921.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3841.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_3937.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4197.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4408.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4366.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4094.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4029.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_441.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4207.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4301.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4272.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4297.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4054.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4098.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4388.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4160.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4231.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4349.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4058.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4166.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4370.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4245.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4409.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4327.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4249.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4057.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4271.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4284.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4113.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_398.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_401.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4324.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4254.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4316.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4336.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4140.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4407.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4317.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4027.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4736.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4607.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4534.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4443.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4660.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4685.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4747.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4730.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4463.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_455.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4608.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4422.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4561.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4626.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4694.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_450.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4518.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4619.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4519.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4414.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4489.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4488.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4552.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4418.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_47.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4625.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4628.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_456.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4586.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4547.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4472.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4507.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4413.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4521.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4630.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4591.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4480.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4666.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4700.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4492.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4957.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4875.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4925.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4817.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4802.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4810.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4970.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4933.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4766.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_485.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4820.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4903.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_495.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4929.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4887.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4865.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4873.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4966.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_482.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_484.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4915.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4851.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4968.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4884.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_48.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4830.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_497.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4866.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4806.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4856.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4805.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4752.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4807.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_494.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4778.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5126.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5155.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5077.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5173.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_521.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5018.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5185.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5151.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5148.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4981.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5225.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4977.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5071.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5030.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5085.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5212.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5001.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5162.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_505.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5105.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5015.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5095.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5163.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5107.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5187.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5069.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5014.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5118.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5080.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4982.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_498.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5159.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5024.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_517.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_4972.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5048.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5034.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5402.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5434.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5347.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5349.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5312.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5442.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5383.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5430.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5346.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5258.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5259.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5480.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5375.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5498.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_529.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5329.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5530.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5252.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5332.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5406.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5316.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5507.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5416.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5418.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_543.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5428.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5337.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5463.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5275.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5356.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_549.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5303.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5318.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5501.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5285.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5461.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5326.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5784.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_570.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5771.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5775.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5555.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5800.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5621.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5781.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5748.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5536.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5787.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5563.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5632.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5618.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5789.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5751.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5603.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5725.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5801.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5547.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_556.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5723.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5586.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5689.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5798.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5670.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5768.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5726.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5653.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5701.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5602.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5666.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5558.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5552.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5682.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5662.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5551.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5988.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6134.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_614.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5907.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6018.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6168.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5836.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5938.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5865.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5903.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6141.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6040.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5808.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_599.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5992.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_586.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_607.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6005.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5934.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5963.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5825.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6136.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5995.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6074.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6072.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6157.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5930.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5828.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_600.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5816.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5914.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5880.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_5829.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6017.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6127.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6091.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6273.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6349.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6307.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6409.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6203.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6380.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6400.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6339.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_629.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6365.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6325.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_636.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6355.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6394.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6291.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6399.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6269.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6321.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6297.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6419.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6198.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6323.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_638.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6350.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6346.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_620.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6183.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6226.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_641.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6442.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Leaf_Scald/aug_0_6239.jpg: (229, 229, 3)
# ...
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9660.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9809.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9718.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9845.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9800.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9834.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9741.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9749.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9703.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9743.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9684.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9726.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9804.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9894.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9913.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9906.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_988.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9980.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9899.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9854.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9914.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9941.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_987.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9864.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9888.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9970.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_999.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9990.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9993.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/aug_0_9991.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (1).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (10).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/20231006_163746.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/20231006_165518.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (100).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/20231006_163740.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/20231006_163255.jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (101).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/20231006_165517(0).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (115).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (104).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (113).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (108).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (110).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (112).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (105).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (116).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (111).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (102).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (109).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (114).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (117).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (107).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (103).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (106).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (11).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (134).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (123).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (131).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (125).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (128).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (118).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (124).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (121).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (122).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (132).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (129).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (130).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (127).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (133).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (13).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (119).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (12).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (120).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (126).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (14).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (154).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (149).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (153).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (138).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (137).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (143).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (142).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (155).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (135).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (147).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (139).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (136).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (15).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (148).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (151).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (150).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (140).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (144).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (141).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (152).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (146).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (145).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (170).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (156).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (161).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (169).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (158).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (163).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (174).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (172).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (162).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (159).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (157).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (164).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (166).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (175).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (173).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (171).jpg: (229, 229, 3)
# Processed image shape for /content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/Healthy_Rice_Leaf/Healthy_rice_leaf (160).jpg: (229, 229, 3)

# %%
# initialize ImageDataGenerator for
# train set with data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# validation set (no augmentation)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# test set (no augmentation)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
# create label encoder
encoder = LabelEncoder()

# transfer label to
# numeric for train and validation dataset
y_train_encoded = encoder.fit_transform(y_train)
y_val_encoded = encoder.transform(y_val)

# one-hot for train and validation dataset
y_train_onehot = to_categorical(y_train_encoded, num_classes=6)
y_val_onehot = to_categorical(y_val_encoded, num_classes=6)

# numeric for test set
y_test_encoded = encoder.transform(y_test)
# Create generators
# for train set
train_generator = train_datagen.flow_from_dataframe(
    dataframe=pd.DataFrame({'image_links': images_train, 'labels': y_train}),
    x_col='image_links',
    y_col='labels',
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical')

# for validation set
val_generator = val_datagen.flow_from_dataframe(
    dataframe=pd.DataFrame({'image_links': images_val, 'labels': y_val}),
    x_col='image_links',
    y_col='labels',
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical')

# for test set
test_generator = test_datagen.flow_from_dataframe(
    dataframe=pd.DataFrame({'image_links': images_test, 'labels': y_test}),
    x_col='image_links',
    y_col='labels',
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical',
    # the order for evaluation
    shuffle=False
)
# Out:
# Found 5978 validated image filenames belonging to 6 classes.
# Found 1278 validated image filenames belonging to 6 classes.
# Found 1281 validated image filenames belonging to 6 classes.

# %%
# check images size in train set
for i in range(6):
    img = load_and_resize_image(images_train[i])
    if img is not None:
        print(f"Image {i} shape: {img.shape}")
batch_images, batch_labels = next(train_generator)
print(f'Batch image shape: {batch_images.shape}')
print(f'Batch label shape: {batch_labels.shape}')
# Out:
# Image 0 shape: (229, 229, 3)
# Image 1 shape: (229, 229, 3)
# Image 2 shape: (229, 229, 3)
# Image 3 shape: (229, 229, 3)
# Image 4 shape: (229, 229, 3)
# Image 5 shape: (229, 229, 3)
# Batch image shape: (32, 229, 229, 3)
# Batch label shape: (32, 6)

# %% [markdown]
# # **6. Xây dựng mô hình InceptionV3**

# %%
# create base model with InceptionV3
base_network = InceptionV3(input_shape=(229, 229, 3), include_top=False, weights='imagenet')

# Set the initial layers of InceptionV3 to be untrainable
for layer in base_network.layers:
  # Freeze classes
    layer.trainable = False

# build model
model = Sequential([
    base_network,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(6, activation='softmax')
])

# Compile model with optimizer
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy'])
# build model and show information
model.build((None, 229, 229, 3))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_95          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,074,534 (84.21 MB)
#  Trainable params: 267,398 (1.02 MB)
#  Non-trainable params: 21,807,136 (83.19 MB)

# %% [markdown]
# # **7. Huấn luyện và tối ưu hóa**

# %%
# prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# adjust learning speed
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)

# train
model.fit(
    train_generator,
    epochs=5,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1072s 6s/step - accuracy: 0.4431 - loss: 2.0964 - val_accuracy: 0.7387 - val_loss: 0.9852 - learning_rate: 0.0010
# Epoch 2/5
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1057s 6s/step - accuracy: 0.6415 - loss: 1.2859 - val_accuracy: 0.7731 - val_loss: 0.8845 - learning_rate: 0.0010
# Epoch 3/5
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1049s 6s/step - accuracy: 0.6882 - loss: 1.1476 - val_accuracy: 0.7895 - val_loss: 0.8414 - learning_rate: 0.0010
# Epoch 4/5
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1048s 6s/step - accuracy: 0.6860 - loss: 1.1039 - val_accuracy: 0.8106 - val_loss: 0.7969 - learning_rate: 0.0010
# Epoch 5/5
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1051s 6s/step - accuracy: 0.7150 - loss: 1.0507 - val_accuracy: 0.8146 - val_loss: 0.7791 - learning_rate: 0.0010

# %%
# Unlock the last 50 layers
for layer in base_network.layers[-50:]:
    layer.trainable = True

# Recompile the model with a smaller Learning Rate
model.compile(
    optimizer=Adam(learning_rate=0.0001),  # ussing smaller learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)

# fine-tune training
history_fine_tune = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1215s 6s/step - accuracy: 0.6869 - loss: 1.1274 - val_accuracy: 0.8670 - val_loss: 0.6246 - learning_rate: 1.0000e-04
# Epoch 2/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1222s 7s/step - accuracy: 0.8189 - loss: 0.7695 - val_accuracy: 0.9210 - val_loss: 0.5076 - learning_rate: 1.0000e-04
# Epoch 3/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1219s 7s/step - accuracy: 0.8784 - loss: 0.6114 - val_accuracy: 0.9437 - val_loss: 0.4411 - learning_rate: 1.0000e-04
# Epoch 4/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1187s 6s/step - accuracy: 0.9177 - loss: 0.5098 - val_accuracy: 0.9546 - val_loss: 0.3840 - learning_rate: 1.0000e-04
# Epoch 5/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1219s 7s/step - accuracy: 0.9379 - loss: 0.4559 - val_accuracy: 0.9679 - val_loss: 0.3455 - learning_rate: 1.0000e-04
# Epoch 6/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1189s 6s/step - accuracy: 0.9458 - loss: 0.4204 - val_accuracy: 0.9726 - val_loss: 0.3367 - learning_rate: 1.0000e-04
# Epoch 7/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1198s 6s/step - accuracy: 0.9551 - loss: 0.3863 - val_accuracy: 0.9757 - val_loss: 0.3135 - learning_rate: 1.0000e-04
# Epoch 8/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1191s 6s/step - accuracy: 0.9661 - loss: 0.3527 - val_accuracy: 0.9797 - val_loss: 0.3033 - learning_rate: 1.0000e-04
# Epoch 9/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1220s 7s/step - accuracy: 0.9700 - loss: 0.3357 - val_accuracy: 0.9781 - val_loss: 0.3047 - learning_rate: 1.0000e-04
# Epoch 10/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1185s 6s/step - accuracy: 0.9719 - loss: 0.3220 - val_accuracy: 0.9851 - val_loss: 0.2685 - learning_rate: 1.0000e-04
# Epoch 11/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1216s 6s/step - accuracy: 0.9747 - loss: 0.3024 - val_accuracy: 0.9804 - val_loss: 0.2747 - learning_rate: 1.0000e-04
# Epoch 12/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1216s 7s/step - accuracy: 0.9785 - loss: 0.2817 - val_accuracy: 0.9820 - val_loss: 0.2586 - learning_rate: 1.0000e-04
# Epoch 13/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1184s 6s/step - accuracy: 0.9791 - loss: 0.2785 - val_accuracy: 0.9844 - val_loss: 0.2474 - learning_rate: 1.0000e-04
# Epoch 14/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1189s 6s/step - accuracy: 0.9787 - loss: 0.2683 - val_accuracy: 0.9875 - val_loss: 0.2378 - learning_rate: 1.0000e-04
# Epoch 15/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1218s 7s/step - accuracy: 0.9832 - loss: 0.2470 - val_accuracy: 0.9875 - val_loss: 0.2319 - learning_rate: 1.0000e-04
# Epoch 16/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1187s 6s/step - accuracy: 0.9782 - loss: 0.2506 - val_accuracy: 0.9867 - val_loss: 0.2239 - learning_rate: 1.0000e-04
# Epoch 17/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1191s 6s/step - accuracy: 0.9817 - loss: 0.2261 - val_accuracy: 0.9883 - val_loss: 0.2100 - learning_rate: 1.0000e-04
# Epoch 18/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1189s 6s/step - accuracy: 0.9845 - loss: 0.2162 - val_accuracy: 0.9898 - val_loss: 0.2009 - learning_rate: 1.0000e-04
# Epoch 19/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1220s 7s/step - accuracy: 0.9811 - loss: 0.2149 - val_accuracy: 0.9875 - val_loss: 0.1985 - learning_rate: 1.0000e-04
# Epoch 20/20
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1221s 7s/step - accuracy: 0.9860 - loss: 0.1994 - val_accuracy: 0.9930 - val_loss: 0.1799 - learning_rate: 1.0000e-04

# %%
# Save in native Keras format
model.save('InceptionV3.keras')

# %% [markdown]
# # **8. Đánh giá hiệu suất**

# %%
# # Plot accuracy graph
plt.figure(figsize=(12, 4))

# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(history_fine_tune.history['accuracy'], label='Độ chính xác (Train)')
plt.plot(history_fine_tune.history['val_accuracy'], label='Độ chính xác (Validation)')
plt.title('Độ chính xác qua các epochs')
plt.xlabel('Epochs')
plt.ylabel('Độ chính xác')
plt.legend()

# Loss graph
plt.subplot(1, 2, 2)
plt.plot(history_fine_tune.history['loss'], label='Mất mát (Train)')
plt.plot(history_fine_tune.history['val_loss'], label='Mất mát (Validation)')
plt.title('Mất mát qua các epochs')
plt.xlabel('Epochs')
plt.ylabel('Mất mát')
plt.legend()

plt.tight_layout()
plt.savefig('/content/gdrive/MyDrive/tieuLuan/dataset/Rice_Leaf_AUG/performance_tracking_chart_InceptionV3.png')
plt.show()

# %%
# predict in test set
# Ensure correct order of data
test_generator.reset()
y_pred = model.predict(test_generator)
# Select the class with the highest probability
y_pred_classes = np.argmax(y_pred, axis=1)

# Get the actual labels from the test set
y_true = test_generator.classes

# Calculate the indexes
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

# print results
print(f"Accuracy: {round(accuracy,4)}")
print(f"Precision: {round(precision,4)}")
print(f"Recall: {round(recall,4)}")
print(f"F1-Score: {round(f1,4)}")

# print Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

# save Confusion Matrix emage
plt.savefig("confusion_matrix_InceptionV3.png", dpi=300, bbox_inches='tight')
plt.show()

# print Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 181s 4s/step
# Accuracy: 0.9813
# Precision: 0.9815
# Recall: 0.9813
# F1-Score: 0.9813
# Classification Report:
#                        precision    recall  f1-score   support
#
# Bacterial_Leaf_Blight       0.97      0.95      0.96       180
#            Brown_Spot       1.00      0.97      0.98       232
#     Healthy_Rice_Leaf       1.00      1.00      1.00       163
#            Leaf_Blast       0.97      0.99      0.98       262
#            Leaf_Scald       0.96      0.99      0.98       200
#         Sheath_Blight       1.00      0.98      0.99       244
#
#              accuracy                           0.98      1281
#             macro avg       0.98      0.98      0.98      1281
#          weighted avg       0.98      0.98      0.98      1281

# %%
# transfer y_true to binary format
n_classes = len(test_generator.class_indices)
y_true_binary = label_binarize(y_true, classes=range(n_classes))

# draw ROC
plt.figure(figsize=(12, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true_binary[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {list(test_generator.class_indices.keys())[i]} (AUC = {roc_auc:.2f})")

# Draw diagonal lines
plt.plot([0, 1], [0, 1], color="gray", linestyle="--")

# Chart Format
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")

# save chart to image file
plt.savefig("roc_auc_curve_InceptionV3.png", dpi=300, bbox_inches='tight')
plt.show()
